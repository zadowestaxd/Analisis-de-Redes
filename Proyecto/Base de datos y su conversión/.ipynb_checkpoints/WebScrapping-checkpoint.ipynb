# %%
import pandas as pd
df_list = pd.read_html('https://www.wikidex.net/wiki/Lista_de_Pok%C3%A9mon_por_aparici%C3%B3n_en_la_vigesimosegunda_temporada')

# %%
len(df_list)
# Out:
# 23

# %%
df_list[0]
# Out:
#                     Pokémon por aparición en el anime             Unnamed: 1
# 0   Serie El Comienzo Lista de Pokémon por aparici...                    NaN
# 1                                   Serie El Comienzo                    NaN
# 2   Lista de Pokémon por aparición en la primera t...                    NaN
# 3   Lista de Pokémon por aparición en la primera t...              T01 • T02
# 4   Serie Oro y Plata Lista de Pokémon por aparici...                    NaN
# 5                                   Serie Oro y Plata                    NaN
# 6   Lista de Pokémon por aparición en la tercera t...                    NaN
# 7   Lista de Pokémon por aparición en la tercera t...        T03 • T04 • T05
# 8   Serie Rubí y Zafiro Lista de Pokémon por apari...                    NaN
# 9                                 Serie Rubí y Zafiro                    NaN
# 10  Lista de Pokémon por aparición en la sexta tem...                    NaN
# 11  Lista de Pokémon por aparición en la sexta tem...  T06 • T07 • T08 • T09
# 12  Serie Diamante y Perla Lista de Pokémon por ap...                    NaN
# 13                             Serie Diamante y Perla                    NaN
# 14  Lista de Pokémon por aparición en la décima te...                    NaN
# 15  Lista de Pokémon por aparición en la décima te...  T10 • T11 • T12 • T13
# 16  Serie Negro y Blanco Lista de Pokémon por apar...                    NaN
# 17                               Serie Negro y Blanco                    NaN
# 18  Lista de Pokémon por aparición en la decimocua...                    NaN
# 19  Lista de Pokémon por aparición en la decimocua...        T14 • T15 • T16
# 20  Serie XY Lista de Pokémon por aparición en la ...                    NaN
# 21                                           Serie XY                    NaN
# 22  Lista de Pokémon por aparición en la decimosép...                    NaN
# 23  Lista de Pokémon por aparición en la decimosép...        T17 • T18 • T19
# 24  Serie Sol y Luna Lista de Pokémon por aparició...                    NaN
# 25                                   Serie Sol y Luna                    NaN
# 26  Lista de Pokémon por aparición en la vigésima ...                    NaN
# 27  Lista de Pokémon por aparición en la vigésima ...        T20 • T21 • T22
# 28  Serie Viajes Pokémon Lista de Pokémon por apar...                    NaN
# 29                               Serie Viajes Pokémon                    NaN
# 30  Lista de Pokémon por aparición en la vigesimot...                    NaN
# 31  Lista de Pokémon por aparición en la vigesimot...        T23 • T24 • T25
# 32  Otras animaciones Lista de Pokémon por aparici...                    NaN
# 33                                  Otras animaciones                    NaN
# 34  Lista de Pokémon por aparición en Pokémon Gene...                    NaN
# 35  Lista de Pokémon por aparición en Pokémon Gene...              GEN • EVO
# 36  Otras listas Lista de Pokémon con diferencias ...                    NaN
# 37                                       Otras listas                    NaN
# 38  Lista de Pokémon con diferencias de sexo por a...                    NaN
# 39  Lista de Pokémon con diferencias de sexo por a...         ♂/♀ • ★ • DMAX

# %%
df_list[1].to_csv('basededatosspace.csv', sep ='\t')

# %%
print(df_list[1].head())
# Out:
#    #     Pokémon Tipo(s) Tipo(s).1  \
# 0  1   Bulbasaur  Planta    Veneno
# 1  3    Venusaur  Planta    Veneno
# 2  5  Charmeleon   Fuego     Fuego
# 3  6   Charizard   Fuego   Volador
# 4  7    Squirtle    Agua      Agua
#
#                         Episodios en los que aparece
# 0           EP215, EP225, EP226, EP227, EP257, EP270
# 1                                              EP250
# 2                                       EP223, EP224
# 3  EP250, EP254, EP255, EP256, EP271, EP272, EP27...
# 4                  EP218, EP269, EP270, EP274, EP275

# %%
df_list[1]['col'].str.get_dummies(sep=',')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df_list[1]['col'].str.get_dummies(sep=',')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'col'
